# %% [markdown]
# ## 1.Import Data and Required Packages
# ### Importing Pandas, Numpy, Matplotlib, Seaborn and Warings Library.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
file_path = r"C:\Users\LENOVO\1. Projects\Bodycode-Anomaly-Detection-Project\artifacts\data_ingestion\data\All_vib.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#            Sensor_Name            TimeStamp  fatigue_mps  fatigue_mmps  \
# 0  V9 VVB001 Fan Motor  2023-11-10 00:27:19       0.0001           0.1
# 1  V9 VVB001 Fan Motor  2023-12-04 00:06:54       0.0001           0.1
# 2  V9 VVB001 Fan Motor  2023-12-01 00:28:04       0.0003           0.3
# 3  V9 VVB001 Fan Motor  2023-12-05 00:18:52       0.0003           0.3
# 4  V9 VVB001 Fan Motor  2023-11-02 00:24:32       0.0001           0.1
#
#    fatigue_ips  impact_mps2  impact_g0  impact_mg0  friction_mps2  \
# 0     0.003937          0.3   0.030591   30.591486            0.1
# 1     0.003937          1.1   0.112169  112.168783            0.3
# 2     0.011811          2.3   0.234535  234.534728            0.5
# 3     0.011811          1.4   0.142760  142.760269            0.4
# 4     0.003937          0.7   0.071380   71.380135            0.2
#
#    friction_g0  friction_mg0  crest  Temperature_C  Temperature_F  \
# 0     0.010197     10.197162    3.9           23.6          74.48
# 1     0.030591     30.591486    3.5           14.2          57.56
# 2     0.050986     50.985810    4.8           22.4          72.32
# 3     0.040789     40.788648    3.8           23.4          74.12
# 4     0.020394     20.394324    3.9           22.5          72.50
#
#          status
# 0  Device is OK
# 1  Device is OK
# 2  Device is OK
# 3  Device is OK
# 4  Device is OK

# %% [markdown]
# ## 2 Data Checks to perform
# 1. Check Missing values
# 2. Check Duplicates
# 3. Check data type
# 4. Check the number of unique values of each column
# 5. Check statistics of data set
# 6. Check various categories present in the different categorical column

# %%
df.isna().sum()
# Out:
# Sensor_Name      0
# TimeStamp        0
# fatigue_mps      0
# fatigue_mmps     0
# fatigue_ips      0
# impact_mps2      0
# impact_g0        0
# impact_mg0       0
# friction_mps2    0
# friction_g0      0
# friction_mg0     0
# crest            0
# Temperature_C    0
# Temperature_F    0
# status           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 52

# %%
# drop duplicates
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#            Sensor_Name            TimeStamp  fatigue_mps  fatigue_mmps  \
# 0  V9 VVB001 Fan Motor  2023-11-10 00:27:19       0.0001           0.1
# 1  V9 VVB001 Fan Motor  2023-12-04 00:06:54       0.0001           0.1
# 2  V9 VVB001 Fan Motor  2023-12-01 00:28:04       0.0003           0.3
# 3  V9 VVB001 Fan Motor  2023-12-05 00:18:52       0.0003           0.3
# 4  V9 VVB001 Fan Motor  2023-11-02 00:24:32       0.0001           0.1
#
#    fatigue_ips  impact_mps2  impact_g0  impact_mg0  friction_mps2  \
# 0     0.003937          0.3   0.030591   30.591486            0.1
# 1     0.003937          1.1   0.112169  112.168783            0.3
# 2     0.011811          2.3   0.234535  234.534728            0.5
# 3     0.011811          1.4   0.142760  142.760269            0.4
# 4     0.003937          0.7   0.071380   71.380135            0.2
#
#    friction_g0  friction_mg0  crest  Temperature_C  Temperature_F  \
# 0     0.010197     10.197162    3.9           23.6          74.48
# 1     0.030591     30.591486    3.5           14.2          57.56
# 2     0.050986     50.985810    4.8           22.4          72.32
# 3     0.040789     40.788648    3.8           23.4          74.12
# 4     0.020394     20.394324    3.9           22.5          72.50
#
#          status
# 0  Device is OK
# 1  Device is OK
# 2  Device is OK
# 3  Device is OK
# 4  Device is OK

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 121178 entries, 0 to 121229
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Sensor_Name    121178 non-null  object
#  1   TimeStamp      121178 non-null  object
#  2   fatigue_mps    121178 non-null  float64
#  3   fatigue_mmps   121178 non-null  float64
#  4   fatigue_ips    121178 non-null  float64
#  5   impact_mps2    121178 non-null  float64
#  6   impact_g0      121178 non-null  float64
#  7   impact_mg0     121178 non-null  float64
#  8   friction_mps2  121178 non-null  float64
#  9   friction_g0    121178 non-null  float64
#  10  friction_mg0   121178 non-null  float64
#  11  crest          121178 non-null  float64
#  12  Temperature_C  121178 non-null  float64
#  13  Temperature_F  121178 non-null  float64
#  14  status         121178 non-null  object
# dtypes: float64(12), object(3)
# memory usage: 14.8+ MB

# %%
df.describe()
# Out:
#          fatigue_mps   fatigue_mmps    fatigue_ips    impact_mps2  \
# count  121178.000000  121178.000000  121178.000000  121178.000000
# mean        0.000128       0.127901       0.005035       0.968416
# std         0.000121       0.121009       0.004764       0.584212
# min         0.000000       0.000000       0.000000       0.200000
# 25%         0.000100       0.100000       0.003937       0.300000
# 50%         0.000100       0.100000       0.003937       1.100000
# 75%         0.000100       0.100000       0.003937       1.100000
# max         0.001600       1.600000       0.062992      38.000000
#
#            impact_g0     impact_mg0  friction_mps2    friction_g0  \
# count  121178.000000  121178.000000  121178.000000  121178.000000
# mean        0.098751      98.750938       0.262133       0.026730
# std         0.059573      59.573069       0.134857       0.013752
# min         0.020394      20.394324       0.100000       0.010197
# 25%         0.030591      30.591486       0.100000       0.010197
# 50%         0.112169     112.168783       0.300000       0.030591
# 75%         0.112169     112.168783       0.300000       0.030591
# max         3.874922    3874.921598       9.500000       0.968730
#
#         friction_mg0          crest  Temperature_C  Temperature_F
# count  121178.000000  121178.000000  121178.000000  121178.000000
# mean       26.730167       3.859389      21.013993      69.825188
# std        13.751620       0.399184       5.469786       9.845615
# min        10.197162       2.300000       9.900000      49.820000
# 25%        10.197162       3.600000      17.100000      62.780000
# 50%        30.591486       3.800000      21.500000      70.700000
# 75%        30.591486       4.100000      24.400000      75.920000
# max       968.730399      11.900000      39.200000     102.560000

# %%
df.nunique()
# Out:
# Sensor_Name           1
# TimeStamp        120776
# fatigue_mps          17
# fatigue_mmps         17
# fatigue_ips          17
# impact_mps2          58
# impact_g0            58
# impact_mg0           58
# friction_mps2        14
# friction_g0          14
# friction_mg0         14
# crest                68
# Temperature_C       286
# Temperature_F       286
# status                1
# dtype: int64

# %%
df.head()
# Out:
#            Sensor_Name            TimeStamp  fatigue_mps  fatigue_mmps  \
# 0  V9 VVB001 Fan Motor  2023-11-10 00:27:19       0.0001           0.1
# 1  V9 VVB001 Fan Motor  2023-12-04 00:06:54       0.0001           0.1
# 2  V9 VVB001 Fan Motor  2023-12-01 00:28:04       0.0003           0.3
# 3  V9 VVB001 Fan Motor  2023-12-05 00:18:52       0.0003           0.3
# 4  V9 VVB001 Fan Motor  2023-11-02 00:24:32       0.0001           0.1
#
#    fatigue_ips  impact_mps2  impact_g0  impact_mg0  friction_mps2  \
# 0     0.003937          0.3   0.030591   30.591486            0.1
# 1     0.003937          1.1   0.112169  112.168783            0.3
# 2     0.011811          2.3   0.234535  234.534728            0.5
# 3     0.011811          1.4   0.142760  142.760269            0.4
# 4     0.003937          0.7   0.071380   71.380135            0.2
#
#    friction_g0  friction_mg0  crest  Temperature_C  Temperature_F  \
# 0     0.010197     10.197162    3.9           23.6          74.48
# 1     0.030591     30.591486    3.5           14.2          57.56
# 2     0.050986     50.985810    4.8           22.4          72.32
# 3     0.040789     40.788648    3.8           23.4          74.12
# 4     0.020394     20.394324    3.9           22.5          72.50
#
#          status
# 0  Device is OK
# 1  Device is OK
# 2  Device is OK
# 3  Device is OK
# 4  Device is OK

# %%
selected_columns = ['Sensor_Name', 'TimeStamp', 'fatigue_mmps', 'impact_mg0', 'friction_mg0', 'crest', 'Temperature_C', 'status']
df = df[selected_columns]

# %%
# Convert TimeStamp column to datetime format
df.loc[:, 'TimeStamp'] = pd.to_datetime(df['TimeStamp'], format='%d/%m/%Y %H:%M:%S')
combined_df1 = df

# make time stamp as index and sort by the index
df = df.set_index('TimeStamp')
df = df.sort_index()
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Convert TimeStamp column to datetime format
# ----> 2 df.loc[:, 'TimeStamp'] = pd.to_datetime(df['TimeStamp'], format='%d/%m/%Y %H:%M:%S')
#       3 combined_df1 = df
#       5 # make time stamp as index and sort by the index
#
# File c:\Users\LENOVO\1. Projects\Bodycode-Anomaly-Detection-Project\venv\Lib\site-packages\pandas\core\tools\datetimes.py:1112, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1110         result = arg.map(cache_array)
#    1111     else:
# -> 1112         values = convert_listlike(arg._values, format)
#    1113         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1114 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\LENOVO\1. Projects\Bodycode-Anomaly-Detection-Project\venv\Lib\site-packages\pandas\core\tools\datetimes.py:488, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     486 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     487 if format is not None and format != "mixed":
# --> 488     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     490 result, tz_parsed = objects_to_datetime64ns(
#     491     arg,
#     492     dayfirst=dayfirst,
#    (...)
#     496     allow_object=True,
#     497 )
#     499 if tz_parsed is not None:
#     500     # We can take a shortcut since the datetime64 numpy array
#     501     # is in UTC
#
# File c:\Users\LENOVO\1. Projects\Bodycode-Anomaly-Detection-Project\venv\Lib\site-packages\pandas\core\tools\datetimes.py:519, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     508 def _array_strptime_with_fallback(
#     509     arg,
#     510     name,
#    (...)
#     514     errors: str,
#     515 ) -> Index:
#     516     """
#     517     Call array_strptime, with fallback behavior depending on 'errors'.
#     518     """
# --> 519     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     520     if any(tz is not None for tz in timezones):
#     521         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File strptime.pyx:534, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:355, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data "2023-11-10 00:27:19" doesn't match format "%d/%m/%Y %H:%M:%S", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
